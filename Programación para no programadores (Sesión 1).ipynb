# %% [markdown]
# <h1 style="font-size:5rem; color: orange">Primeros pasos</h1>

# %% [markdown]
# # Ritual de iniciación

# %%
#Imprime tu primer "hola mundo"

# %% [markdown]
# # Imprime tu nombre

# %% [markdown]
# # Declara tu nombre en una variable

# %% [markdown]
# # Declara tus nombres por separado en una lista

# %% [markdown]
# # Asigna tu edad

# %% [markdown]
# # ¿Cuál es tu ciudad natal?

# %% [markdown]
# # Realiza tu presentación

# %% [markdown]
# # Realiza una presentación de tu familia

# %% [markdown]
# # Operaciones básicas

# %% [markdown]
# <h1 style="font-size:3rem; color: orange">Problema </h1>

# %% [markdown]
# # En la pizzería donde trabajas como aprendiz de programación y cocinero, te han asignado la tarea de crear un programa básico para ayudar en la preparación de pizzas. La pizzería ofrece diferentes tipos de masa, quesos y suplementos, y cada cliente puede personalizar su pizza.

# %% [markdown]
# ![WhatsApp%20Image%202023-12-13%20at%209.54.21%20PM.jpeg](attachment:WhatsApp%20Image%202023-12-13%20at%209.54.21%20PM.jpeg)

# %% [markdown]
# # Define una lista que contenga al menos tres tipos de masa disponibles para las pizzas.

# %% [markdown]
# # Crea una lista que incluya al menos tres tipos de queso.

# %% [markdown]
# # Prepara una lista con diferentes suplementos que los clientes pueden agregar a sus pizzas.

# %% [markdown]
# # Prepara una receta secreta que incluya tu verdura favorita, tu fruta favorita y una especia especial.

# %% [markdown]
# # ¡Prepara!
